# %%
from astropy import time

from poliastro.twobody.orbit import Orbit
from poliastro.bodies import Earth
from poliastro.frames import Planes
from poliastro.plotting import StaticOrbitPlotter
from poliastro.neos import Callisto
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-dd003a437902> in <module>
#       5 from poliastro.frames import Planes
#       6 from poliastro.plotting import StaticOrbitPlotter
# ----> 7 from poliastro.neos import Callisto
#
# ImportError: cannot import name 'Callisto' from 'poliastro.neos' (D:\anaconda3\lib\site-packages\poliastro\neos\__init__.py)

# %%
ganymed = Orbit.from_sbdb("1035")  # Ganymed IAU number
amor = Orbit.from_sbdb("2001221")  # Amor SPK-ID
eros = Orbit.from_sbdb("2000433")  # Eros SPK-ID

frame = StaticOrbitPlotter(plane=Planes.EARTH_ECLIPTIC)
frame.plot(ganymed, label="Ganymed")
frame.plot(amor, label="Amor")
frame.plot(eros, label="Eros");

# %%
neows.orbit_from_spk_id(2001221)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d280b56427c3> in <module>
# ----> 1 neows.orbit_from_spk_id(2001221)
#
# NameError: name 'neows' is not defined
